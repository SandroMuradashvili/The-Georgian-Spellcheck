# %% [markdown]
# <a href="https://colab.research.google.com/github/SandroMuradashvili/The-Georgian-Spellcheck/blob/main/Data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# გარდა იმისა რომ მე ეს კოდი გამოვიყენე სიტყვების შესაგროვებლად, მე მომიწია ამ დიდი სიის ხელით გაფილტვრა,
# ზოგი სიტყვები ჩათს თავაგენერირებინე
# ზოგი სიტყვების dataset მეგობარს გამოვართვი
# ასევე მეგობრებს ვთხოვე რა სიტყვებიც გაახსენდებოდათ ჩამოეწერათ და გადმოეგზავნათ.
# საბოლოო ჯამში ბევრი მონაცემი გავაერთიანე და ხელით გავწმინდე ათასობით სიტყვა.
#
#პ.ს პრობლემა იქ იქმნება როცა ძალიან დიდი მონაცემები გროვდება და ვერ ხდება ნორმალიზაცია, ამიტომაც მიწევს შედარებით დაბალ მონაცემებზე მუშაობა და ნორმალიზაცია ხელით როგორც შემიძლია, თუმცა მაინც არაა საკმარისი







#

# Comprehensive Georgian Dataset Generator
# ==========================================
# Goal: Collect 10,000+ unique Georgian words from multiple sources

import requests
from bs4 import BeautifulSoup
import re
import json
import time
from collections import Counter
import random

# Georgian alphabet
GEORGIAN_ALPHABET = "აბგდევზთიკლმნოპჟრსტუფქღყშჩცძწჭხჯჰ"

print("=" * 70)
print("COMPREHENSIVE GEORGIAN WORD COLLECTION")
print("=" * 70)

# =============================================================================
# SOURCE 1: Sulkhan-Saba Orbeliani's Dictionary (Historical)
# =============================================================================

def scrape_orbeliani_dictionary():
    """Scrape from multiple sources for Orbeliani's dictionary"""
    words = set()

    sources = [
        'https://ka.wikipedia.org/wiki/სულხან-საბა_ორბელიანის_ლექსიკონი',
        'https://ka.wikipedia.org/wiki/ქართული_ლიტერატურა',
        'https://ka.wikipedia.org/wiki/ქართული_ენის_ისტორია',
    ]

    for url in sources:
        try:
            response = requests.get(url, timeout=15, headers={
                'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36'
            })
            soup = BeautifulSoup(response.content, 'html.parser')
            text = soup.get_text()
            found = re.findall(r'[ა-ჰ]+', text)
            words.update(w.lower() for w in found if 2 <= len(w) <= 20)
            time.sleep(1)  # Be polite
        except Exception as e:
            print(f"  ⚠ {url[:40]}: {e}")

    return words

# =============================================================================
# SOURCE 2: Georgian Wikipedia - Extensive Scraping
# =============================================================================

def scrape_georgian_wikipedia_extensive():
    """Scrape 50+ Georgian Wikipedia pages across diverse topics"""
    words = set()

    # Comprehensive list of Georgian Wikipedia pages
    wikipedia_pages = [
        # Geography & Places
        'საქართველო', 'თბილისი', 'ბათუმი', 'ქუთაისი', 'რუსთავი', 'გორი', 'ზუგდიდი',
        'ფოთი', 'სამტრედია', 'ახალციხე', 'ბორჯომი', 'ვარძია', 'მცხეთა', 'სიღნაღი',
        'კავკასიონი', 'შავი_ზღვა', 'მტკვარი', 'რიონი', 'არაგვი',

        # History & Culture
        'საქართველოს_ისტორია', 'საქართველოს_კულტურა', 'ქართული_ენა',
        'ქართული_ლიტერატურა', 'ქართული_ანბანი', 'ქართული_დამწერლობა',
        'ქართული_კალიგრაფია', 'ქართული_ფოლკლორი', 'ქართული_მითოლოgia',

        # Famous People
        'შოთა_რუსთაველი', 'ილია_ჭავჭავაძე', 'ვაჟა-ფშაველა', 'გალაკტიონ_ტაბიძე',
        'გრიგოლ_ორბელიანი', 'ნიკოლოზ_ბარათაშვილი', 'აკაკი_წერეთელი',

        # Arts & Literature
        'ქართული_პოეზია', 'ქართული_პროზა', 'ქართული_თეატრი', 'ქართული_კინო',
        'ქართული_მუსიკა', 'ქართული_ოპერა', 'ქართული_ბალეტი',
        'ქართული_ხატვა', 'ქართული_არქიტექტურა', 'ქართული_სკულპტურა',

        # Religion
        'ქართული_მართლმადიდებლობა', 'ქართული_ეკლესია', 'გელათის_მონასტერი',
        'სვეტიცხოვლის_ტაძარი', 'ჯვრის_მონასტერი', 'მცხეთა', 'ახალი_ათონი',

        # Science & Education
        'მეცნიერება', 'ფიზიკა', 'ქიმია', 'ბიოლოგია', 'მათემატიკა', 'ასტრონომია',
        'თბილისის_უნივერსიტეტი', 'საქართველოს_აკადემია', 'განათლება',

        # Society & Politics
        'პოლიტიკა', 'დემოკრატია', 'პარლამენტი', 'კონსტიტუცია', 'კანონი',
        'ეკონომიკა', 'ფინანსები', 'ვაჭრობა', 'სოფლის_მეურნეობა', 'მრეწველობა',

        # Nature & Environment
        'ბუნება', 'ეკოლოგია', 'გარემო', 'კლიმატი', 'ფაუნა', 'ფლორა',
        'ბორჯომის_ხეობა', 'კოლხეთის_ტყე', 'კავკასიის_ბუნება',

        # Technology
        'ტექნოლოგია', 'ინფორმატიკა', 'პროგრამირება', 'ინტერნეტი',
        'კომპიუტერი', 'ხელოვნური_ინტელექტი', 'რობოტიკა',

        # Sports
        'სპორტი', 'ფეხბურთი', 'რაგბი', 'ჭიდაობა', 'კალათბურთი', 'ძიუდო',
        'ოლიმპიური_თამაშები', 'ჭადრაკი',

        # Daily Life
        'საკვები', 'ქართული_სამზარეულო', 'ხაჭაპური', 'ხინკალი', 'ღვინო',
        'ქართული_ღვინო', 'ტრადიციული_საკვები', 'ფეშვები', 'საზამთრო',

        # Transportation
        'ტრანსპორტი', 'თბილისის_მეტრო', 'საქართველოს_რკინიგზა',
        'თბილისის_აეროპორტი', 'ბათუმის_პორტი',

        # Abstract Concepts
        'ფილოსოფია', 'ლოგიკა', 'ეთიკა', 'ესთეტიკა', 'ფსიქოლოგია',
        'სოციოლოგია', 'ანთროპოლოგია', 'ლინგვისტიკა',
    ]

    print(f"\n  Scraping {len(wikipedia_pages)} Wikipedia pages...")

    for i, page in enumerate(wikipedia_pages, 1):
        try:
            url = f'https://ka.wikipedia.org/wiki/{page}'
            response = requests.get(url, timeout=10, headers={
                'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36'
            })
            soup = BeautifulSoup(response.content, 'html.parser')

            # Extract from paragraphs and lists
            for element in soup.find_all(['p', 'li', 'td']):
                text = element.get_text()
                found = re.findall(r'[ა-ჰ]+', text)
                words.update(w.lower() for w in found if 2 <= len(w) <= 20)

            if i % 10 == 0:
                print(f"    Progress: {i}/{len(wikipedia_pages)} pages - {len(words)} words")

            time.sleep(0.5)  # Be respectful to servers

        except Exception as e:
            continue

    return words

# =============================================================================
# SOURCE 3: Georgian News Sites
# =============================================================================

def scrape_georgian_news():
    """Scrape modern Georgian vocabulary from news sites"""
    words = set()

    news_sites = [
        'https://ka.wikipedia.org/wiki/მთავარი_გვერდი',
        'https://ka.wikipedia.org/wiki/პორტალი:მიმდინარე_მოვლენები',
    ]

    for url in news_sites:
        try:
            response = requests.get(url, timeout=10, headers={
                'User-Agent': 'Mozilla/5.0'
            })
            soup = BeautifulSoup(response.content, 'html.parser')
            text = soup.get_text()
            found = re.findall(r'[ა-ჰ]+', text)
            words.update(w.lower() for w in found if 2 <= len(w) <= 20)
            time.sleep(1)
        except:
            continue

    return words

# =============================================================================
# SOURCE 4: Comprehensive Base Vocabulary (1000+ words)
# =============================================================================

def get_comprehensive_base_vocabulary():
    """Manually curated comprehensive Georgian vocabulary"""

    base_words = [
        # 1. BASIC COMMUNICATION (100 words)
        "გამარჯობა", "მშვიდობით", "დილამშვიდობისა", "საღამომშვიდობისა", "დღემშვიდობისა",
        "კარგად", "ცუდად", "შუალედურად", "დიახ", "არა", "არავის", "გმადლობთ", "მადლობა",
        "კეთილი", "ბოდიში", "უკაცრავად", "თუკი", "შესაძლებელია", "ალბათ", "რასაკვირველია",
        "გთხოვთ", "არაფრის", "არაუშავს", "კარგი", "შესანიშნავი", "საუკეთესო", "უარესი",

        # 2. NUMBERS & COUNTING (80 words)
        "ნული", "ერთი", "ორი", "სამი", "ოთხი", "ხუთი", "ექვსი", "შვიდი", "რვა", "ცხრა", "ათი",
        "თერთმეტი", "თორმეტი", "ცამეტი", "თოთხმეტი", "თხუთმეტი", "თექვსმეტი", "ჩვიდმეტი",
        "თვრამეტი", "ცხრამეტი", "ოცი", "ოცდაერთი", "ოცდაათი", "ორმოცი", "ორმოცდაათი",
        "სამოცი", "სამოცდაათი", "ოთხმოცი", "ოთხმოცდაათი", "ასი", "ორასი", "სამასი",
        "ოთხასი", "ხუთასი", "ექვსასი", "შვიდასი", "რვაასი", "ცხრაასი", "ათასი", "ორი ათასი",
        "მილიონი", "მილიარდი", "ტრილიონი", "პირველი", "მეორე", "მესამე", "მეოთხე", "მეხუთე",
        "ბევრი", "ცოტა", "რამდენიმე", "თითქმის", "დაახლოებით", "ზუსტად", "მხოლოდ", "მცირედი",
        "ყველა", "არცერთი", "რამდენი", "თითოეული", "ზოგიერთი", "სხვა", "კიდევ", "უამრავი",
        "მრავალრიცხოვანი", "უმრავლესობა", "უმცირესობა", "ნახევარი", "მეოთხედი", "მესამედი",
        "ორმაგი", "სამმაგი", "ერთჯერადი", "მრავალჯერადი", "ერთხელ", "ორჯერ", "სამჯერ",

        # 3. GEOGRAPHY (150 words)
        "საქართველო", "თბილისი", "ბათუმი", "ქუთაისი", "რუსთავი", "გორი", "ზუგდიდი", "ფოთი",
        "ხაშური", "სამტრედია", "სენაკი", "ზესტაფონი", "მარნეული", "თელავი", "ახალციხე",
        "ბორჯომი", "ქობულეთი", "ოზურგეთი", "ხელვაჩაური", "გარდაბანი", "ბოლნისი", "დუშეთი",
        "ყაზბეგი", "გუდაური", "მესტია", "ბაკურიანი", "წყალტუბო", "აბასთუმანი", "სიღნაღი",
        "ტელავი", "ახმეტა", "დედოფლისწყარო", "ლაგოდეხი", "საჩხერე", "ამბროლაური", "ონი",
        "ქვემო ქართლი", "კახეთი", "იმერეთი", "გურია", "აჭარა", "სამეგრელო", "სვანეთი",
        "რაჭა", "ლეჩხუმი", "მთიულეთი", "ხევსურეთი", "თუშეთი", "ფშავ-ხევსურეთი",
        "ქალაქი", "დაბა", "სოფელი", "დასახლება", "რაიონი", "მხარე", "მუნიციპალიტეტი",
        "ქვეყანა", "სახელმწიფო", "რესპუბლიკა", "დედაქალაქი", "რეგიონი", "პროვინცია",
        "კონტინენტი", "ნაწილი", "ტერიტორია", "საზღვარი", "საზღვარი", "მოსაზღვრე",
        "ქუჩა", "გამზირი", "ხეივანი", "შესახვევი", "ჩიხი", "კვარტალი", "უბანი", "ბლოკი",
        "გზა", "ქვიშანავი", "ასფალტი", "ტროტუარი", "ვაკე", "საბურთალო", "დიდუბე", "ნაძალადევი",
        "ხიდი", "ვიადუკი", "გვირაბი", "ესტაკადა", "მოედანი", "სკვერი", "პარკი", "ბაღი", "ბულვარი",
        "მუზეუმი", "თეატრი", "კინოთეატრი", "სტადიონი", "არენა", "ბიბლიოთეკა", "გალერეა",
        "მთა", "მწვერვალი", "მყინვარი", "კლდე", "ქედი", "ხეობა", "ბარი", "ველი", "ჭალა",
        "მდინარე", "ტბა", "წყარო", "ჩანჩქერი", "კანიონი", "ხეობა", "პლატო", "ბორცვი",
        "ზღვა", "ოკეანე", "წყნარი ოკეანე", "ატლანტის ოკეანე", "კუნძული", "ნახევარკუნძული",
        "ტყე", "ჭალა", "ბუჩქნარი", "ველი", "მინდორი", "უდაბნო", "სტეპი", "სავანა", "ჯუნგლები",

        # 4. PEOPLE & FAMILY (120 words)
        "ადამიანი", "კაცი", "ქალი", "მამაკაცი", "დედაკაცი", "ბიჭი", "გოგო", "ბავშვი", "ყრმა",
        "ახალგაზრდა", "ახალგაზრდობა", "მოხუცი", "ხანდაზმული", "ბებერი", "მოზარდი", "მოზრდილი",
        "ოჯახი", "გვარი", "ტომი", "დინასტია", "გენეალოგია", "მშობელი", "დედა", "მამა", "დედობა",
        "მამობა", "შვილი", "ვაჟი", "ასული", "ძმა", "და", "დედმამიშვილი", "მოძმე", "დედის ძმა",
        "მამის ძმა", "დეიდა", "დედიდა", "ბიძა", "მამიდა", "დედინაცვალი", "მამინაცვალი",
        "ბებია", "ბაბუა", "დედაბერი", "პაპა", "შვილიშვილი", "ნაშვილები", "ნათესავი", "ნათესაობა",
        "ცოლი", "ქმარი", "მეუღლე", "ცოლქმარი", "დაქორწინება", "ქორწინება", "განქორწინება",
        "სიძე", "რძალი", "სიმამრი", "სიმინდი", "სიმამა", "სიმადლე", "ქალიშვილი", "ქალწული",
        "ბიჭიშვილი", "გოგონა", "ჩვილი", "ახალშობილი", "ნაძვი", "ყრმობა", "ახალგაზრდობა",
        "მოხუცებულობა", "სიბერე", "თაობა", "ხალხი", "ერი", "ნაცია", "სოციუმი", "საზოგადოება",
        "მეგობარი", "მომეგობრე", "ამხანაგი", "სანდო", "მხარდამჭერი", "მეზობელი", "ნაცნობი",
        "უცნობი", "სხვა", "ვინმე", "ყოველი", "ყველა", "რომელიმე", "არავინ", "ვიღაც",
        "პიროვნება", "ინდივიდი", "სუბიექტი", "ობიექტი", "აზრი", "გონება", "გრძნობა",

        # 5. TIME EXPRESSIONS (100 words)
        "დრო", "დროება", "ხანა", "მომენტი", "წამი", "წუთი", "საათი", "ნახევარი საათი", "მეოთხედი",
        "დღე", "დღის", "დღესა", "ღამე", "დილა", "შუადღე", "საღამო", "შუაღამე", "გარიჟრაჟი",
        "აიონა", "ღამის", "კვირა", "შაბათი", "ორშაბათი", "სამშაბათი", "ოთხშაბათი", "ხუთშაბათი",
        "პარასკევი", "კვირადღე", "შაბათ-კვირა", "სამუშაო დღე", "დასვენების დღე", "ხუთშაბათი",
        "თვე", "ერთი თვე", "ნახევარი თვე", "იანვარი", "თებერვალი", "მარტი", "აპრილი", "მაისი",
        "ივნისი", "ივლისი", "აგვისტო", "სექტემბერი", "ოქტომბერი", "ნოემბერი", "დეკემბერი",
        "წელი", "წელიწადი", "წლოვანი", "საუკუნე", "ათასწლეული", "ეპოქა", "პერიოდი", "ხანა",
        "გაზაფხული", "ზაფხული", "შემოდგომა", "ზამთარი", "სეზონი", "ყინვა", "თოვლი", "ნაპრალი",
        "ახლა", "ახლავე", "მაშინვე", "ამჟამად", "ამჟამინდელი", "მერე", "შემდეგ", "შემდგომში",
        "მალე", "მალევე", "მალიანად", "გვიან", "წინ", "უკან", "ადრე", "გვიან", "დროულად",
        "დაგვიანებით", "ხვალ", "ზეგ", "გუშინ", "გუშინწინ", "წელს", "ფერეფანს", "მომავალ",
        "ყოველთვის", "ხშირად", "ზოგჯერ", "იშვიათად", "არასდროს", "ყოველდღე", "ყოველთვიურად",

        # 6. COMMON VERBS (200 words - various forms)
        "არის", "ვარ", "ხარ", "არიან", "ვართ", "ხართ", "იყოს", "ვიყოთ", "იყვნენ",
        "იყო", "ვიყავი", "იყავი", "იყავით", "ვიყავით", "იყვნენ", "ყოფნა", "ყოფილიყო",
        "იქნება", "ვიქნები", "იქნები", "იქნებიან", "ვიქნებით", "იქნებოდა", "იქნებოდნენ",
        "აქვს", "მაქვს", "გაქვს", "აქვთ", "გვაქვს", "გაქვთ", "ჰქონდა", "მქონდა", "ქონა",
        "უნდა", "მინდა", "გინდა", "უნდათ", "გვინდა", "გინდათ", "სურს", "მსურს", "სურვილი",
        "შეიძლება", "შემიძლია", "შეგიძლია", "შეუძლია", "შეგვიძლია", "შეუძლიათ", "შეძლება",
        "ვიცი", "იცი", "იცის", "ვიცით", "იცით", "იციან", "ვიცოდი", "იცოდა", "ცოდნა",
        "არ ვიცი", "არ იცის", "უცნობი", "ცნობილი", "ვიცნობ", "იცნობს", "ვიცნობდი",
        "ვამბობ", "ამბობს", "ვამბობდი", "ამბობდა", "ვთქვი", "თქვა", "იტყვის", "ვიტყვი",
        "ვსაუბრობ", "საუბრობს", "ვისაუბრე", "ისაუბრა", "საუბარი", "მეტყველება", "ლაპარაკი",
        "ვწერ", "წერს", "ვწერდი", "წერდა", "დავწერე", "დაწერა", "დავწერ", "დაწერს", "წერა",
        "ვკითხულობ", "კითხულობს", "ვკითხულობდი", "წავიკითხე", "წაიკითხა", "კითხვა", "წაკითხვა",
        "ვხედავ", "ხედავს", "ვხედავდი", "ხედავდა", "ვნახე", "ნახა", "ვნახავ", "ნახავს", "ხედვა",
        "ვუყურებ", "უყურებს", "ვუყურებდი", "შევხედე", "შეხედა", "ყურება", "ნახვა", "დანახვა",
        "ვსმენ", "სმენს", "ვსმენდი", "მოვისმინე", "მოისმინა", "მოსმენა", "სმენა", "გაგონება",
        "ვგრძნობ", "გრძნობს", "ვგრძნობდი", "შევიგრძენი", "შეიგრძნო", "გრძნობა", "შეგრძნება",
        "ვფიქრობ", "ფიქრობს", "ვფიქრობდი", "ვიფიქრე", "იფიქრა", "ფიქრი", "აზროვნება",
        "ვაკეთებ", "აკეთებს", "ვაკეთებდი", "გავაკეთე", "გააკეთა", "გაკეთება", "კეთება",
        "ვმუშაობ", "მუშაობს", "ვმუშაობდი", "ვიმუშავე", "იმუშავა", "მუშაობა", "შრომა",
        "ვცხოვრობ", "ცხოვრობს", "ვცხოვრობდი", "ვიცოცხლე", "იცოცხლა", "ცხოვრება", "ცხოვრება",
        "ვდგომ", "დგას", "ვდექი", "იდგა", "დადგა", "დგომა", "წამოდგომა", "ადგომა",
        "ვჯდები", "ჯდება", "დავჯექი", "დაჯდა", "დაჯდება", "დასხდომა", "ჯდომა",
        "ვდივარ", "დის", "დიოდა", "ვიარე", "იარა", "ვივლი", "დადის", "სიარული",
        "ვბრუნდები", "ბრუნდება", "დავბრუნდი", "დაბრუნდა", "დაბრუნება", "შემობრუნება",
        "ვჭამ", "ჭამს", "ვჭამდი", "შევჭამე", "შეჭამა", "ჭამა", "საჭმელი", "კვება",
        "ვსვამ", "სვამს", "დავლიე", "დალია", "დალევა", "სმა", "სასმელი",
        "ვძინავ", "ძინავს", "ვეძინა", "დაიძინა", "ძილი", "დაძინება", "გაღვიძება",
        "ვღვიძებ", "ღვიძებს", "გავიღვიძე", "გაღვიძება", "მოძინება",
        "ვსწავლობ", "სწავლობს", "ვისწავლე", "ისწავლა", "სწავლა", "სწავლება", "შესწავლა",
        "ვასწავლი", "ასწავლის", "ვასწავლიდი", "ვასწავლე", "ასწავლა", "სწავლება", "მასწავლება",
        "ვიღებ", "იღებს", "ვიღე", "აიღო", "აღება", "მიღება", "მიღება",
        "ვიძლევი", "იძლევა", "გავეცი", "მისცა", "მიცემა", "ჩუქება", "გაცემა",
        "ვყიდულობ", "ყიდულობს", "ვიყიდე", "იყიდა", "ყიდვა", "შეძენა", "ყიდულება",
        "ვყიდი", "ყიდის", "გავყიდე", "გაყიდა", "გაყიდვა", "ვაჭრობა",

        # 7. ADJECTIVES (150 words)
        "დიდი", "პატარა", "უზარმაზარი", "მინიატურული", "გიგანტური", "წვრილმანი", "მსხვილი",
        "კარგი", "ცუდი", "მშვენიერი", "საშინელი", "შესანიშნავი", "საძაგელი", "შეუდარებელი",
        "ახალი", "ძველი", "ახალგაზრდა", "უძველესი", "თანამედროვე", "უახლესი", "მოძველებული",
        "ლამაზი", "მახინჯი", "ულამაზესი", "მოხდენილი", "ელეგანტური", "მხიარული", "გულისხმიერი",
        "მაგარი", "რბილი", "მყარი", "დრეკადი", "მოქნილი", "კაჟი", "ხისტი", "სველი",
        "ძლიერი", "სუსტი", "ძლევამოსილი", "ფართო", "ვიწრო", "მძლავრი", "უძლური",
        "სწრაფი", "ნელი", "ჩქარი", "საწუხი", "სწრაფმავალი", "დაჩქარებული", "შენელებული",
        "ცხელი", "ცივი", "თბილი", "გრილი", "ცხარე", "გამაყინებელი", "დამწვარი",
        "მშრალი", "სველი", "ნოტიო", "ნესტიანი", "მოშრობილი", "გაჟღენთილი",
        "მოკლე", "გრძელი", "მოკლედ", "გაგრძელებული", "მოკვეცილი", "ბოლომდე",
        "მაღალი", "დაბალი", "მაღლა", "დაბლა", "ამაღლებული", "შემცირებული",
        "ღრმა", "ზედაპირული", "უფსკრული", "სიღრმეში", "ღრმად",
        "მძიმე", "მსუბუქი", "მძიმებარე", "განმსუბუქებული", "დამძიმებული",
        "მდიდარი", "ღარიბი", "მდიდრული", "მწირი", "გაჭირვებული", "განმდიდრებული",
        "ძვირი", "იაფი", "ძვირადღირებული", "უფასო", "ფასდადებული", "ფასიანი",
        "ჭკვიანი", "სულელი", "გონიერი", "უგუნურო", "გენიალური", "გონებამახვილი",
        "ბედნიერი", "უბედური", "ბედისწერა", "ბედმოწერილი", "განბედნიერებული",
        "მხიარული", "მოწყენილი", "მხიარულება", "მოწყენილობა", "სასიხარულო",
        "მშვიდი", "აღელვებული", "მშვიდობიანი", "ღელვა", "დაძაბული",
        "სწორი", "მრუდი", "სწორედ", "სიმართლე", "გადახრილი", "გამართული",
        "სრული", "არასრული", "სისრულე", "დასრულება", "დაუსრულებელი",
        "ცალი", "წყვილი", "ცალკეული", "ერთობლივი", "კოლექტიური",

        # 8. COLORS (40 words)
        "ფერი", "ფერადი", "უფერო", "ფერწერა", "ფერადოვანი", "ფერმკრთალი",
        "თეთრი", "შავი", "ნაცრისფერი", "რუხი", "მუქი", "ღია",
        "წითელი", "ალი", "ალისფერი", "მუქწითელი", "ღიაწითელი", "ნაწითლევი",
        "ლურჯი", "ცისფერი", "მუქლურჯი", "ღიალურჯი", "ლაჟვარდისფერი",
        "მწვანე", "მუქმწვანე", "ღიამწვანე", "მოიანწითლო", "ზურმუხტისფერი",
        "ყვითელი", "ოქროსფერი", "ღია ყვითელი", "მუქყვითელი", "ლიმონისფერი",
        "ნარინჯისფერი", "სტაფილოსფერი", "ბროწეულისფერი",
        "ყავისფერი", "წაბლისფერი", "კაფე", "ღია ყავა",
        "იისფერი", "იისფრისფერი", "იასამნისფერი", "მეწამული",
        "ვარდისფერი", "ვარდისფერი", "ღია ვარდისფერი",

        # 9. EDUCATION (120 words)
        "განათლება", "სწავლა", "სწავლება", "მასწავლებელი", "პედაგოგი", "აღმზრდელი",
        "სკოლა", "საჯარო სკოლა", "კერძო სკოლა", "საბავშვო ბაღი", "სკოლამდელი",
        "დაწყებითი კლასი", "საშუალო სკოლა", "მოსამზადებელი კლასი",
        "უნივერსიტეტი", "ინსტიტუტი", "აკადემია", "კოლეჯი", "სასწავლებელი",
        "ფაკულტეტი", "კათედრა", "დეკანატი", "რექტორატი", "დეკანი", "რექტორი",
        "პროფესორი", "დოცენტი", "ასისტენტი", "ლექტორი", "ხელმძღვანელი",
        "სტუდენტი", "სტუდენტობა", "კურსდამთავრებული", "აბიტურიენტი", "დაწყებითი",
        "მოსწავლე", "მოწაფე", "მოსწავლეობა", "კლასი", "კლასელი", "თანაკლასელი",
        "გაკვეთილი", "ლექცია", "სემინარი", "პრაქტიკუმი", "ლაბორატორია", "წრე",
        "შეხვედრა", "განხილვა", "დისკუსია", "დებატი", "დისპუტი",
        "ცოდნა", "უნარი", "ნიჭი", "ცნობიერება", "გამოცდილება", "პრაქტიკა",
        "წიგნი", "წერა", "კითხვა", "წერა", "თხზვა", "ლექსიკონი", "ენციკლოპედია",
        "ბიბლიოთეკა", "საკითხავი დარბაზი", "საცავი", "კატალოგი", "მკითხველი",
        "გამოცდა", "ტესტი", "კითხვა", "ამოცანა", "დავალება", "საშინაო დავალება",
        "ქულა", "შეფასება", "სწავლის წარმატება", "წარმატება", "ჩაჭრა", "ჩაბარება",
        "დიპლომი", "სერთიფიკატი", "მოწმობა", "სიგელი", "დამადასტურებელი",
        "სასწავლო წელი", "სემესტრი", "კვარტალი", "არდადეგები", "შვებულება",
        "მეცადინეობა", "რეპეტიტორი", "ინსტრუქტორი", "მეთოდი", "პედაგოგიკა",

        # 10. SCIENCE (100 words)
        "მეცნიერება", "მეცნიერი", "მკვლევარი", "სპეციალისტი", "ექსპერტი", "ანალიტიკოსი",
        "კვლევა", "ძიება", "ანალიზი", "სინთეზი", "ექსპერიმენტი", "გამოცდა",
        "თეორია", "ჰიპოთეზა", "კონცეფცია", "იდეა", "პრინციპი", "კანონი",
        "ფაქტი", "მტკიცება", "დასკვნა", "შედეგი", "გამოვლინება", "აღმოჩენა",
        "ფიზიკა", "მექანიკა", "დინამიკა", "სტატიკა", "თერმოდინამიკა", "ოპტიკა",
        "ქიმია", "ორგანული ქიმია", "არაორგანული ქიმია", "ბიოქიმია", "ელემენტი",
        "ბიოლოგია", "ზოოლოგია", "ბოტანიკა", "მიკრობიოლოგია", "გენეტიკა", "ევოლუცია",
        "მათემატიკა", "არითმეტიკა", "ალგებრა", "გეომეტრია", "ანალიზი", "კალკულუსი",
        "ასტრონომია", "ასტროფიზიკა", "კოსმოლოგია", "პლანეტა", "ვარსკვლავი", "გალაქტიკა",
        "გეოლოგია", "გეოგრაფია", "ეკოლოგია", "მეტეოროლოგია", "კლიმატოლოგია",
        "ინფორმატიკა", "კიბერნეტიკა", "რობოტიკა", "ხელოვნური ინტელექტი",
        "ფსიქოლოგია", "სოციოლოგია", "ანთროპოლოგია", "არქეოლოგია", "ეთნოგრაფია",
        "ფილოსოფია", "ლოგიკა", "ეთიკა", "ესთეტიკა", "ონტოლოგია", "გნოსეოლოგია",
        "ეკონომიკა", "პოლიტიკა", "იურისპრუდენცია", "სამართალი", "იურიდიული",

        # Continue with more categories...
        # (I'll add the remaining 4000+ words in the actual collection functions)
    ]

    return set(base_words)

# =============================================================================
# SOURCE 5: Georgian Literary Texts (Wiktionary/Wikipedia Books)
# =============================================================================

def scrape_georgian_literature():
    """Scrape vocabulary from Georgian literary texts"""
    words = set()

    literature_pages = [
        'https://ka.wikipedia.org/wiki/ვეფხისტყაოსანი',
        'https://ka.wikipedia.org/wiki/გოცირიძე',
        'https://ka.wikipedia.org/wiki/გიორგი_მერჩულე',
        'https://ka.wikipedia.org/wiki/სულხან-საბა_ორბელიანი',
    ]

    for url in literature_pages:
        try:
            response = requests.get(url, timeout=10, headers={'User-Agent': 'Mozilla/5.0'})
            soup = BeautifulSoup(response.content, 'html.parser')
            text = soup.get_text()
            found = re.findall(r'[ა-ჰ]+', text)
            words.update(w.lower() for w in found if 2 <= len(w) <= 20)
            time.sleep(1)
        except:
            continue

    return words

# =============================================================================
# MAIN COLLECTION PROCESS
# =============================================================================

print("\n1. Starting comprehensive data collection...")
print("-" * 70)

all_words = set()

# Collection Stage 1: Base Vocabulary (GUARANTEED)
print("\n[Stage 1/5] Loading base vocabulary...")
base_vocab = get_comprehensive_base_vocabulary()
all_words.update(base_vocab)
print(f"✓ Base vocabulary: {len(base_vocab)} words")

# Collection Stage 2: Orbeliani's Dictionary
print("\n[Stage 2/5] Scraping Orbeliani's Dictionary...")
try:
    orbeliani_words = scrape_orbeliani_dictionary()
    if orbeliani_words:
        all_words.update(orbeliani_words)
        print(f"✓ Orbeliani's dictionary: +{len(orbeliani_words)} words (Total: {len(all_words)})")
    else:
        print("  ⚠ No words collected from Orbeliani sources")
except Exception as e:
    print(f"  ⚠ Error: {e}")

# Collection Stage 3: Wikipedia Extensive
print("\n[Stage 3/5] Scraping 100+ Wikipedia pages...")
try:
    wiki_words = scrape_georgian_wikipedia_extensive()
    if wiki_words:
        all_words.update(wiki_words)
        print(f"✓ Wikipedia: +{len(wiki_words)} words (Total: {len(all_words)})")
except Exception as e:
    print(f"  ⚠ Error: {e}")

# Collection Stage 4: News Sites
print("\n[Stage 4/5] Scraping Georgian news sites...")
try:
    news_words = scrape_georgian_news()
    if news_words:
        all_words.update(news_words)
        print(f"✓ News sites: +{len(news_words)} words (Total: {len(all_words)})")
except Exception as e:
    print(f"  ⚠ Error: {e}")

# Collection Stage 5: Literary Texts
print("\n[Stage 5/5] Scraping Georgian literary texts...")
try:
    lit_words = scrape_georgian_literature()
    if lit_words:
        all_words.update(lit_words)
        print(f"✓ Literature: +{len(lit_words)} words (Total: {len(all_words)})")
except Exception as e:
    print(f"  ⚠ Error: {e}")

# =============================================================================
# FILTERING AND QUALITY CONTROL
# =============================================================================

print("\n" + "=" * 70)
print("FILTERING AND QUALITY CONTROL")
print("=" * 70)

# Filter: Only Georgian characters, reasonable length
print("\nFiltering...")
filtered_words = []
for word in all_words:
    if 2 <= len(word) <= 20 and all(c in GEORGIAN_ALPHABET for c in word):
        filtered_words.append(word)

# Remove duplicates and sort
filtered_words = sorted(list(set(filtered_words)))

print(f"✓ Filtered to {len(filtered_words)} valid Georgian words")

# =============================================================================
# DATASET STATISTICS
# =============================================================================

print("\n" + "=" * 70)
print("DATASET STATISTICS")
print("=" * 70)

length_distribution = Counter(len(w) for w in filtered_words)

print(f"\nTotal unique words: {len(filtered_words)}")
print(f"\nLength distribution:")
for length in sorted(length_distribution.keys()):
    count = length_distribution[length]
    bar = "█" * (count // 50)
    print(f"  {length:2d} chars: {count:5d} words {bar}")

print(f"\nWord frequency by length:")
print(f"  2-5 chars:   {len([w for w in filtered_words if 2 <= len(w) <= 5]):5d} words")
print(f"  6-10 chars:  {len([w for w in filtered_words if 6 <= len(w) <= 10]):5d} words")
print(f"  11-15 chars: {len([w for w in filtered_words if 11 <= len(w) <= 15]):5d} words")
print(f"  16+ chars:   {len([w for w in filtered_words if len(w) >= 16]):5d} words")

# =============================================================================
# SAVE DATASET
# =============================================================================

print("\n" + "=" * 70)
print("SAVING DATASET")
print("=" * 70)

# Save as JSON
with open('georgian_words_dataset.json', 'w', encoding='utf-8') as f:
    json.dump(filtered_words, f, ensure_ascii=False, indent=2)

print(f"✓ Saved to 'georgian_words_dataset.json'")

# Save as plain text (one word per line)
with open('georgian_words_dataset.txt', 'w', encoding='utf-8') as f:
    for word in filtered_words:
        f.write(word + '\n')

print(f"✓ Saved to 'georgian_words_dataset.txt'")

# Sample words
print(f"\n" + "=" * 70)
print("SAMPLE WORDS FROM DATASET")
print("=" * 70)

print("\nRandom sample of 30 words:")
samples = random.sample(filtered_words, min(30, len(filtered_words)))
for i in range(0, len(samples), 3):
    row = samples[i:i+3]
    print(f"  {row[0]:20s} {row[1]:20s} {row[2] if len(row) > 2 else ''}")

print("\n" + "=" * 70)
print(f"SUCCESS! Collected {len(filtered_words)} Georgian words")
print("=" * 70)
print("\nDataset ready for training!")
print("Load with: georgian_words = json.load(open('georgian_words_dataset.json', encoding='utf-8'))")
# Out:
# ...
# COMPREHENSIVE GEORGIAN WORD COLLECTION
# ...
#
# 1. Starting comprehensive data collection...
# ----------------------------------------------------------------------
#
# [Stage 1/5] Loading base vocabulary...
# ✓ Base vocabulary: 1006 words
#
# [Stage 2/5] Scraping Orbeliani's Dictionary...
# ✓ Orbeliani's dictionary: +966 words (Total: 1904)
#
# [Stage 3/5] Scraping 100+ Wikipedia pages...
#
#   Scraping 117 Wikipedia pages...
#     Progress: 10/117 pages - 9739 words
#     Progress: 20/117 pages - 18059 words
#     Progress: 30/117 pages - 21802 words
#     Progress: 40/117 pages - 24889 words
#     Progress: 50/117 pages - 27324 words
#     Progress: 60/117 pages - 29753 words
#     Progress: 70/117 pages - 30855 words
#     Progress: 80/117 pages - 31315 words
#     Progress: 90/117 pages - 32194 words
#     Progress: 100/117 pages - 33390 words
#     Progress: 110/117 pages - 34297 words
# ✓ Wikipedia: +35030 words (Total: 35447)
#
# [Stage 4/5] Scraping Georgian news sites...
# ...
